# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

file_path = "../data/2024-October 31, 2025 Monthly Criminal Activity Dataset.xlsx"

# %%
# --- Load the data and do the main calculation ---
try:
    df_crime = pd.read_excel(file_path)
    print("---------- Excel data file loaded successfully! ----------")
    
    print("\n---------- First 5 rows of data: ----------")
    print(df_crime.head())
    
    if 'Neighborhood' in df_crime.columns:
        # We create a new variable to hold the counts
        neighborhood_crime_counts = df_crime['Neighborhood'].value_counts()
        print("\n---------- Successfully calculated crime counts for all neighborhoods. ----------")
    else:
        print("\n!!! ERROR: 'Neighborhood' column not found in the Excel file !!!")
        print("Found columns are: ")
        print(df_crime.columns.to_list())

except FileNotFoundError:
    print(f"!!! ERROR: File Not Found !!!")
    print(f"Please check if your file path is correct: {file_path}")
    print("Ensure your notebook is in 'personal_notebooks' and your file is in 'data'.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# ---------- Excel data file loaded successfully! ----------
#
# ---------- First 5 rows of data: ----------
#   Report_Number ReportedDate ReportedTime  Hour DayofWeek ReportedMonth  \
# 0  PGHP24000024   2024-01-01        00:31     0    Monday           Jan
# 1  PGHP24000024   2024-01-01        00:31     0    Monday           Jan
# 2  PGHP24000024   2024-01-01        00:31     0    Monday           Jan
# 3  PGHP24000024   2024-01-01        00:31     0    Monday           Jan
# 4  PGHP24000017   2024-01-01        00:21     0    Monday           Jan
#
#                            NIBRS_Coded_Offense NIBRS_Offense_Code  \
# 0                       13A AGGRAVATED ASSAULT                13A
# 1                             13C INTIMIDATION                13C
# 2                       90Z ALL OTHER OFFENSES                90Z
# 3                        23H ALL OTHER LARCENY                23H
# 4  9999 Vehicle Offense (Not NIBRS Reportable)                999
#
# ...

# %%
# --- Show the Top 20 (Most Crime) ---

print("---------- Preliminary Analysis: Total incidents per neighborhood (Top 20) ----------")
print(neighborhood_crime_counts.head(20))
print("\n---------- Generating visualization... ----------")
plt.figure(figsize=(12, 7)) 

neighborhood_crime_counts.head(20).plot(kind='bar',
                                     title='Top 20 Neighborhoods by Crime Incidents (2024-2025)',
                                     ylabel='Number of Incidents')

plt.tight_layout()
plt.show()
# Out:
# ---------- Preliminary Analysis: Total incidents per neighborhood (Top 20) ----------
# Neighborhood
# Central Business District    7218
# South Side Flats             4631
# Carrick                      2242
# Shadyside                    1993
# East Allegheny               1917
# East Liberty                 1913
# Bloomfield                   1498
# Knoxville                    1444
# Mount Washington             1401
# Squirrel Hill South          1352
# Brookline                    1300
# Homewood South               1254
# Allentown                    1249
# Crawford-Roberts             1061
# Marshall-Shadeland           1048
# North Shore                  1047
# Sheraden                     1042
# Homewood North               1019
# Hazelwood                     990
# Bluff                         971
# Name: count, dtype: int64
#
# ---------- Generating visualization... ----------

# %%
# --- Show the Bottom 20 (Least Crime) ---

bottom_20_neighborhoods = neighborhood_crime_counts.tail(20).sort_values(ascending=True)
print("---------- Preliminary Analysis: Neighborhoods with FEWEST incidents (Top 20 Safest) ----------")
print(bottom_20_neighborhoods)
print("\n---------- Generating visualization for 'safest' neighborhoods... ----------")
plt.figure(figsize=(12, 7)) 

bottom_20_neighborhoods.plot(kind='bar',
                          title='Top 20 "Safest" Neighborhoods (Lowest Crime Incidents 2024-2025)',
                          ylabel='Number of Incidents')

plt.tight_layout()
plt.show()
# Out:
# ---------- Preliminary Analysis: Neighborhoods with FEWEST incidents (Top 20 Safest) ----------
# Neighborhood
# Saint Clair           25
# Ridgemont             33
# Chartiers             38
# New Homestead         54
# Swisshelm Park        66
# East Carnegie         78
# Esplen                79
# Summer Hill           83
# Oakwood               88
# Regent Square         97
# Hays                 107
# Fairywood            108
# Mount Oliver         111
# Arlington Heights    123
# Allegheny West       130
# Glen Hazel           132
# Windgap              150
# Spring Garden        157
# Morningside          200
# Polish Hill          200
# Name: count, dtype: int64
#
# ---------- Generating visualization for 'safest' neighborhoods... ----------
