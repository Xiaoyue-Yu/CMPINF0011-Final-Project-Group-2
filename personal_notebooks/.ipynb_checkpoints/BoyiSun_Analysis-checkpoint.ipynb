# %% [markdown]
# # Infrastructure Sub-metric(the number of park facilities)
# - **Dataset:** City_facilitis_of_Pittsburgh
# - **Data path:** `data/City_Facilities_of_Pittsburgh.csv`
# - **Contributor:** Boyi Sun

# %% [markdown]
# ## Work Completed (Check-in)
# - Loaded the city facilities data of Pittsburgh using pandas
# - Analyzed the primary users of city facility
# - Counted the facility number and the citipark number by neighborhood respectively
# - Visualization :
#     - Primary_user of facilities
#     - Top 20 neighborhoods by the number of facilities
#     - Top 20 neighborhoods by the number of park facilities
#
# ## Future Work
# - Add a reasonable weight on different type of citypark facilities. For example, give a lager weight to the citypark facilities in the type "senior", making it more reasonable for our overall metric: Best neighborhood for **retirees**"
# - Take other relavent data into considertaion.
# - Exclude the data point that may be not suitable for analysis on retirees, such as the facilities in the playgound for the children.
#
# ## Key Findings
# - The top three primary users in the dataset is `Department of Public Work`, `Citiparks`, and `Department of Public Safety`.
# - The number of facilities is varied from neighborhood to neighborhood.
# - The number of park facilities is not much different. Adding a weight on different types may make the analysis more strict to retirees.

# %%
#Import package and data
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data_path="../data/City_Facilities_of_Pittsburgh.csv"
df_facility=pd.read_csv(data_path)

# %%
# Data loading 
print("First 20 rows of data")
print(df_facility.head(20))
# Out:
# First 20 rows of data
#     _id          id  parcel_id inactive  \
# 0     1   650726265  120-J-300        f
# 1     2   783044037    2-H-284        f
# 2     3  1997158435   23-R-157        f
# 3     4   204824684   10-F-198        f
# 4     5   472140955  013-K-314        f
# 5     6   984285720   13-F-217        f
# 6     7  2110346447   13-K-314        f
# 7     8   263802473    3-M-404        f
# 8     9   271629667    49-K-61        f
# 9    10   436558867        NaN        f
# 10   11  1534014655   122-L-50        f
# 11   12   287640271   122-L-50        f
# 12   13   970468255    36-L-81        f
# 13   14  2105474885   17-R-120        f
# 14   15  1042325852   17-R-120        f
# 15   16   635191366   17-R-120        f
# 16   17   940841117   17-R-120        f
# 17   18  1890556433    35-G-26        f
# 18   19   160770425    26-D-11        f
# 19   20   836558540    26-D-11        f
#
#                                                  name rentable        type  \
# 0                           57th Street Park Building        f     Storage
# 1                     Albert Turk Graham Park Shelter        f     Shelter
# 2   Allegheny Northside Senior Center and Hazlett ...        t      Senior
# 3                             Ammon Recreation Center        f        Pool
# 4                     Arlington Field Lights Building        f     Utility
# 5                         Arlington Recreation Center        t    Activity
# 6                            Arlington Pool Restrooms        f        Pool
# 7                            Armstrong Field Building        f   Restrooms
# 8                               Arsenal Park Building        f   Restrooms
# 9                     Asphalt Plant Equipment Shelter        f     Service
# 10                             Asphalt Plant Garage 2        f     Storage
# 11                 Asphalt Plant Testing Lab Building        f     Service
# 12                        Banksville Concession Stand        f  Concession
# 13          Banksville Concession Stand and Restrooms        f  Concession
# 14                     Banksville Deck Hockey Benches        f      Dugout
# 15                             Banksville Park Gazebo        f     Shelter
# 16               Banksville Pool Building and Shelter        t        Pool
# 17              Beechview Senior and Community Center        f      Senior
# 18                     Bloomfield Deck Hockey Benches        f      Dugout
# 19              Bloomfield Pool and Recreation Center        f    Pool/Rec
#
#                   primary_user  address_number          street  ...  \
# 0   Department of Public Works             NaN         57TH ST  ...
# 1   Department of Public Works            39.0         VINE ST  ...
# 2                    CitiParks             5.0  ALLEGHENY SQ E  ...
# 3                    CitiParks          2217.0     BEDFORD AVE  ...
# 4                    CitiParks             0.0     STERLING ST  ...
# 5                    CitiParks          2201.0    SALISBURY ST  ...
# 6                    CitiParks          1630.0     STERLING ST  ...
# 7                    CitiParks          1201.0        SARAH ST  ...
# 8                    CitiParks          3900.0       BUTLER ST  ...
# 9   Department of Public Works             NaN    LOCKWAY EAST  ...
# 10  Department of Public Works          7777.0    LOCKWAY EAST  ...
# 11  Department of Public Works          7777.0    LOCKWAY EAST  ...
# 12  Department of Public Works             NaN     CARNAHAN RD  ...
# 13  Department of Public Works          1461.0       CRANE AVE  ...
# 14  Department of Public Works             NaN       CRANE AVE  ...
# 15  Department of Public Works             NaN       CRANE AVE  ...
# 16                   CitiParks          1461.0       CRANE AVE  ...
# 17                   CitiParks          1555.0    BROADWAY AVE  ...
# 18  Department of Public Works             NaN             NaN  ...
# 19                   CitiParks           408.0         ELLA ST  ...
#
#            neighborhood council_district  ward        tract  \
# 0   Upper Lawrenceville                7  10.0  42003101100
# 1      Crawford-Roberts                6   3.0  42003030500
# 2      Allegheny Center                1  22.0  42003562700
# 3     Bedford Dwellings                6   5.0  42003050900
# 4     South Side Slopes                3  16.0  42003160800
# 5     South Side Slopes                3  16.0  42003160800
# 6     South Side Slopes                3  16.0  42003160800
# 7      South Side Flats                3  17.0  42003170200
# 8   Lower Lawrenceville                7   6.0  42003060300
# 9         Highland Park                9  12.0  42003980100
# 10        Highland Park                9  12.0  42003980100
# 11        Highland Park                9  12.0  42003980100
# 12           Banksville                2  20.0  42003202300
# 13           Banksville                2  20.0  42003202300
# 14           Banksville                2  20.0  42003202300
# 15           Banksville                2  20.0  42003202300
# 16           Banksville                2  20.0  42003202300
# 17            Beechview                4  19.0  42003191600
# 18           Bloomfield                7   8.0  42003080200
# 19           Bloomfield                7   8.0  42003080200
#
#     public_works_division  pli_division  police_zone  fire_zone   latitude  \
# 0                     2.0          10.0          2.0        3-5  40.485666
# 1                     3.0           3.0          2.0        2-1  40.440458
# 2                     1.0          22.0          1.0        1-6  40.453099
# 3                     3.0           5.0          2.0        2-5  40.448735
# 4                     3.0          16.0          3.0       4-22  40.418152
# 5                     3.0          16.0          3.0       4-22  40.419269
# 6                     3.0          16.0          3.0       4-22  40.417753
# 7                     3.0          17.0          3.0       4-24  40.428318
# 8                     2.0           6.0          2.0        3-3  40.466753
# 9                     2.0          12.0          5.0       3-15  40.484910
# 10                    2.0          12.0          5.0       3-15  40.485102
# 11                    2.0          12.0          5.0       3-15  40.484953
# 12                    5.0          20.0          6.0        4-9  40.407328
# 13                    5.0          20.0          6.0        4-9  40.414416
# 14                    5.0          20.0          6.0        4-9  40.414327
# 15                    5.0          20.0          6.0        4-9  40.414653
# 16                    5.0          20.0          6.0        4-9  40.414784
# 17                    5.0          19.0          6.0       4-28  40.410741
# 18                    2.0           8.0          5.0        3-6  40.462618
# 19                    2.0           8.0          5.0        3-1  40.462133
#
#     longitude
# 0  -79.946450
# 1  -79.984104
# 2  -80.005343
# 3  -79.977856
# 4  -79.974471
# 5  -79.975215
# 6  -79.974688
# 7  -79.986166
# 8  -79.960344
# 9  -79.906370
# 10 -79.906146
# 11 -79.906825
# 12 -80.037968
# 13 -80.039552
# 14 -80.038920
# 15 -80.039286
# 16 -80.040176
# 17 -80.024363
# 18 -79.953666
# 19 -79.953589
#
# [20 rows x 22 columns]

# %%
# Analysis of facilities primary users
primary_users_counts=df_facility["primary_user"].value_counts()
primary_users_counts.plot(kind='bar',title="Primary_user of facilities")
plt.show()

# %%
# All facilities counts
neighborhood_facility_counts=df_facility["neighborhood"].value_counts()
neighborhood_facility_counts.rename("Facility_counts",inplace=True)
print(neighborhood_facility_counts.head(20))

# Visualization
neighborhood_facility_counts.plot(kind="bar",title="Top 20 neighborhoods by the number of facilities",ylabel="Number of facilities in the neighborhood",fontsize=5)
plt.show()
# Out:
# neighborhood
# Highland Park                30
# Squirrel Hill South          29
# Perry North                  20
# Brookline                    19
# Strip District               15
# Hazelwood                    14
# Brighton Heights             14
# Carrick                      12
# Lincoln-Lemington-Belmar     11
# South Side Slopes            11
# Elliott                      11
# Morningside                  10
# Shadyside                     9
# Point Breeze                  8
# Central Business District     8
# Squirrel Hill North           7
# Mount Washington              7
# Sheraden                      7
# Lower Lawrenceville           7
# Banksville                    7
# Name: Facility_counts, dtype: int64
# <Axes: title={'center': 'Top 20 neighborhoods by facility number'}, xlabel='neighborhood', ylabel='Number of facilities in the neighborhood'>

# %%
# Park facilities counts
park_facility=df_facility[df_facility["primary_user"]=="CitiParks"]
neighborhood_park_facility_counts=park_facility["neighborhood"].value_counts()
neighborhood_park_facility_counts.rename("Park_facilities_counts",inplace=True)
print(neighborhood_park_facility_counts.head(20))

# Visualization
neighborhood_park_facility_counts.plot(kind="bar",title="Top 20 neighborhoods by the number of park facilities",fontsize=5,ylabel="Number of park facilities")
plt.show()
# Out:
# neighborhood
# South Side Slopes           6
# Squirrel Hill South         6
# Lincoln-Lemington-Belmar    5
# Point Breeze                5
# Morningside                 5
# Brighton Heights            4
# Beechview                   4
# Elliott                     4
# South Side Flats            4
# Brookline                   4
# Polish Hill                 4
# Sheraden                    4
# Beltzhoover                 4
# Mount Washington            4
# Squirrel Hill North         4
# Allegheny Center            4
# Hazelwood                   3
# Shadyside                   3
# Bloomfield                  3
# Highland Park               3
# Name: Park_counts, dtype: int64
