# %% [markdown]
# # Air Quality Sub-metric (Daily AQI) — Personal Notebook
#
# **Sub-metric:** Air Quality Cleanliness (daily), measured by worst-of-day AQI per site.
# **Dataset:** Daily Air Condition (2024–2025)
# **File Used:** `data/2024-October 31, 2025 Daily Air Condition Dataset.xlsx`
#
# ---
#
# ## Work Completed (Check-in)
#
# - Loaded the 2024–2025 Daily Air Condition dataset using pandas (sliced to **2024-01-01 → 2025-10-31**).
# - Cleaned and verified fields; standardized column names.
# - Aggregated to **daily** per site: for each site × day, used **max AQI across pollutants** to represent overall daily exposure.
# - Computed site-level metrics: **median_daily_aqi**, **p90_daily_aqi**, **healthy_rate** (AQI ≤ 100), and a composite **BNAS** score.
# - Generated two visualizations:
#   - **Air Quality Ranking by Site (daily)** for 2024–2025.
#   - **Best Site Daily AQI Time Series** (with 3-day rolling median).
#
# ## Future Work
#
# - **Map Sites → Neighborhoods:** Use neighborhood boundaries to aggregate site results to official Pittsburgh neighborhoods.
# - **Normalize & Combine:** Integrate additional datasets for the team’s combined metric; test weight sensitivity and alternative scalings.
# - **Parameterization:** Allow easy toggling of date windows and weights in the composite score.
#
# ## Key Findings (2024-01-01 → 2025-10-31)
#
# - Top-ranked site by BNAS: **Lawrenceville 2** (BNAS ≈ **93.6**).
# - Daily AQI varies by site; some locations show consistently low typical exposure and very few days above AQI 100.
# - Using worst-of-day AQI ensures spikes from any pollutant are reflected in the daily exposure perspective.
#
# **Top 3 sites (summary):**
# |   rank | site                  |   BNAS |   median_daily_aqi |   p90_daily_aqi | healthy_rate   |
# |-------:|:----------------------|-------:|-------------------:|----------------:|:---------------|
# |      1 | Lawrenceville 2       |  93.64 |                  3 |             6   | 100.0%         |
# |      2 | Liberty               |  83.64 |                  8 |            36.1 | 100.0%         |
# |      3 | Glassport High Street |  81.82 |                 15 |            31   | 100.0%         |

# %%
# Parameters & Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# Date range
START = pd.Timestamp("2024-01-01")
END   = pd.Timestamp("2025-11-01")  # right-open; includes 2025-10-31

# Data paths: prefer repo-style relative path, fall back to /mnt/data for this environment
DATA_PATHS = [
    Path("../data/2024-October 31, 2025 Monthly Air Condition Dataset.xlsx"),
]

OUT_DIR = Path("outputs")
OUT_DIR.mkdir(parents=True, exist_ok=True)

def find_existing(path_candidates):
    for p in path_candidates:
        if p.exists():
            return p
    raise FileNotFoundError("Could not find input Excel at any of: " + "; ".join(map(str, path_candidates)))

DATA_XLSX = Path("../data/2024-October 31, 2025 Daily Air Condition Dataset.xlsx")
print("Using data file:", DATA_XLSX)
# Out:
# Using data file: ..\data\2024-October 31, 2025 Daily Air Condition Dataset.xlsx

# %%
# Helper functions (standalone to keep this notebook self-contained)

def normalize_columns(df: pd.DataFrame) -> pd.DataFrame:
    out = df.copy()
    out.columns = (
        out.columns.str.strip()
        .str.lower()
        .str.replace(r"[^a-z0-9]+", "_", regex=True)
        .str.strip("_")
    )
    return out

def inv_percentile(series: pd.Series) -> pd.Series:
    if len(series) <= 1:
        return pd.Series([1.0]*len(series), index=series.index)
    ranks = series.rank(method="average", ascending=True)
    return 1.0 - (ranks - 1) / (len(series) - 1)

def pos_percentile(series: pd.Series) -> pd.Series:
    if len(series) <= 1:
        return pd.Series([1.0]*len(series), index=series.index)
    ranks = series.rank(method="average", ascending=False)
    return 1.0 - (ranks - 1) / (len(series) - 1)

def compute_bnas(df_agg: pd.DataFrame,
                 median_col: str,
                 p90_col: str,
                 healthy_rate_col: str,
                 weights=None) -> pd.DataFrame:
    if weights is None:
        weights = {"median": 0.5, "p90": 0.3, "healthy": 0.2}

    med = df_agg[median_col]
    p90 = df_agg[p90_col]
    hr  = df_agg[healthy_rate_col]

    median_score  = inv_percentile(med.fillna(med.max()))
    p90_score     = inv_percentile(p90.fillna(p90.max()))
    healthy_score = pos_percentile(hr.fillna(0))

    bnas = (
        weights["median"] * median_score
        + weights["p90"] * p90_score
        + weights["healthy"] * healthy_score
    ) * 100.0

    out = df_agg.copy()
    out["BNAS"] = bnas
    out = out.sort_values("BNAS", ascending=False).reset_index(drop=True)
    out["rank"] = np.arange(1, len(out) + 1)
    return out

# %%
# Load, aggregate (daily), compute metrics and BNAS
all_sheets = pd.read_excel(DATA_XLSX, sheet_name=None)
dfs = []
for name, sdf in all_sheets.items():
    sdf = normalize_columns(sdf)
    sdf["__sheet__"] = str(name)
    dfs.append(sdf)
df = pd.concat(dfs, ignore_index=True)

need = ["date", "site", "parameter", "index_value"]
missing = [c for c in need if c not in df.columns]
if missing:
    raise RuntimeError(f"Missing required columns: {missing}")

df["timestamp"] = pd.to_datetime(df["date"], errors="coerce")
df = df.dropna(subset=["timestamp"])
df = df[(df["timestamp"] >= START) & (df["timestamp"] < END)].copy()
df["date_day"] = df["timestamp"].dt.normalize()

# daily worst-of-day AQI per site
daily = (
    df.groupby(["site", "date_day"])["index_value"]
    .max()
    .reset_index()
    .rename(columns={"index_value": "aqi"})
)

daily["healthy_flag"] = daily["aqi"] <= 100.0

agg = daily.groupby("site").agg(
    days_observed=("healthy_flag", "count"),
    healthy_days=("healthy_flag", "sum"),
    median_daily_aqi=("aqi", "median"),
    p90_daily_aqi=("aqi", lambda s: np.nanquantile(s.dropna(), 0.9)),
    sd_daily_aqi=("aqi", "std"),
).reset_index()

agg["healthy_rate"] = agg["healthy_days"] / agg["days_observed"]

ranked = compute_bnas(
    agg,
    median_col="median_daily_aqi",
    p90_col="p90_daily_aqi",
    healthy_rate_col="healthy_rate",
    weights={"median": 0.5, "p90": 0.3, "healthy": 0.2},
)

ranked_path = OUT_DIR / "air_quality_site_metrics_daily_2024_2025.csv"
ranked.to_csv(ranked_path, index=False)
ranked.head(10)
# Out:
#                     site  days_observed  healthy_days  median_daily_aqi  \
# 0        Lawrenceville 2            670           670               3.0
# 1                Liberty            670           670               8.0
# 2  Glassport High Street            669           669              15.0
# 3               Clairton            667           667              33.0
# 4           Parkway East            666           666              33.0
# 5                 Avalon            668           668              34.0
# 6          Lawrenceville            670           667              35.0
# 7             Pittsburgh            668           668              36.0
# 8              Liberty 2            667           667              41.0
# 9      Harrison Township            670           668              38.0
#
#    p90_daily_aqi  sd_daily_aqi  healthy_rate       BNAS  rank
# 0            6.0      2.039008      1.000000  93.636364     1
# 1           36.1     16.295885      1.000000  83.636364     2
# 2           31.0      9.907892      1.000000  81.818182     3
# 3           56.0     15.721521      1.000000  65.454545     4
# 4           56.0     15.305518      1.000000  65.454545     5
# 5           57.0     15.758749      1.000000  53.181818     6
# 6           49.0     12.343598      0.995522  46.363636     7
# 7           57.0     15.543331      1.000000  44.090909     8
# 8           64.0     18.049059      1.000000  20.909091     9
# 9           64.0     15.812664      0.997015  20.909091    10

# %%
# Visualizations (one chart per figure, matplotlib only; no manual colors)
import matplotlib.pyplot as plt

# Ranking bar chart
plt.figure(figsize=(10,6))
plt.bar(ranked["site"], ranked["BNAS"])
plt.xticks(rotation=60, ha="right")
plt.ylabel("Best Neighborhood Air Score (0–100)")
plt.title("Air Quality Ranking by Site (Daily, 2024-01-01 to 2025-10-31)")
plt.tight_layout()
out_rank = OUT_DIR / "site_air_quality_ranking_daily_2024_2025.png"
plt.savefig(out_rank, dpi=150, bbox_inches="tight")
plt.show()

# Best site's daily series
best_site = ranked.loc[0, "site"]
best_daily = daily[daily["site"] == best_site].sort_values("date_day")

plt.figure(figsize=(10,5))
plt.plot(best_daily["date_day"], best_daily["aqi"], label="Daily AQI")
best_daily = best_daily.set_index("date_day")
best_daily["roll_med"] = best_daily["aqi"].rolling(window=3, min_periods=1).median()
plt.plot(best_daily.index, best_daily["roll_med"], linestyle="--", label="Rolling Median (3d)")
plt.axhline(100.0, linestyle=":", linewidth=1.5, label="AQI=100 (Acceptable Threshold)")
plt.legend()
plt.xlabel("Date")
plt.ylabel("AQI")
plt.title(f"{best_site}: Daily AQI (2024-01-01 to 2025-10-31)")
plt.tight_layout()
out_ts = OUT_DIR / "best_site_timeseries_daily_2024_2025.png"
plt.savefig(out_ts, dpi=150, bbox_inches="tight")
plt.show()

print("Saved to:", out_rank)
print("Saved to:", out_ts)
# Out:
# Saved to: outputs\site_air_quality_ranking_daily_2024_2025.png
# Saved to: outputs\best_site_timeseries_daily_2024_2025.png
